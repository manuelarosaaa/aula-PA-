# %% [markdown]
# <a href="https://colab.research.google.com/github/manuelarosaaa/aula-PA-/blob/main/PA_aula_06_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula de programação e algoritimos
#
# * calcular a área de uma sala
#
# #entrada
#
# Medir o comprimento da sala
# Medir largura da sala
#
# # processamento
#
# fazer a multiplicação do comprimento pela largura
#
# # saída

# %%
# ENTRADA
comprimento = 7 # metros
largura = 4 # metros

# %%
# processamento


area = comprimento * largura

# %%
print (f" area total da sala é: {area} metros quadrados")
# print (" area total da sala é: ", area,  " metros quadrados")
# Out:
#  area total da sala é: 28 metros quadrados

# %%
#Entrada

lado = 2

# processamento

resultado = lado * lado

# saída

print (f"o resultado do quadrado é :{resultado} ")
# Out:
# o resultado do quadrado é :4

# %% [markdown]
# # Entrada
#
# Ler um numero
#
# # processamento
#
# Multiplicar número vezes 2
#
# # saida
#
# Mostrar o dobro do número

# %%
# Entrada

numero = 3

# peocessamento

dobro = numero * 2

# Saída

print (f"o dobro do numero digitado é: {dobro}")
# Out:
# o dobro do numero digitado é: 6

# %% [markdown]
# Operadores aritiméticos
#
# Soma = +
# Subtração = -
# Multiplicação = *
# Divusão = /

# %%
# Entrada

nota_1 = 2
nota_2 = 3
nota_3 = 4
nota_4 = 5

# processamento

media = (nota_1 + nota_2 + nota_3 + nota_4) /4

# saída

print (f"media dos alunos é igual a : {media}")
# Out:
# media dos alunos é igual a : 3.5
