# %% [markdown]
# <a href="https://colab.research.google.com/github/manuelarosaaa/aula-PA-/blob/main/aula_20_mar%C3%A7o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# aula online dia  20 de março

# %%
#entrada
a = int(4)
b = int (2)

# processamento

soma = a + b

# saída

print (f"soma é : {soma}")
# Out:
# soma é : 6

# %%
# entrada

a = int (4)
b = int(2)

# processamento

subtracao = a - b

# saída

print (f"resultado da subtração é: {subtracao}")
# Out:
# resultado da subtração é: 2

# %%
# entrada

a = 5
b = 3

# processamento

multiplicacao = a * b

# saída

print(f"resultado da multiplicação é : {multiplicacao}")
# Out:
# resultado da multiplicação é : 15

# %%
# entrada

a = float(9)
b = float(7)

# processamento

divisao = a/b

# saída

print(f"resultado é : {divisao}")
# Out:
# resultado é : 1.2857142857142858

# %%
# entrada

n1 = 5
n2 = 10
n3 = 8

# processamento

media = (n1+n2+n3)/3

# saída

print(f"resultado é:{media}")
# Out:
# resultado é:7.666666666666667

# %%
# entrada

a = int(6)

# processamento

dobro = a*2
metade = a/2
divisaoportres = a/3

# saida

print(f" resultado do dobro é: {dobro}")
print(f" resultado da metade  é: {metade}")
print(f" resultado  da divisão  é: {divisaoportres}")
# Out:
#  resultado do dobro é: 12
#  resultado da metade  é: 3.0
#  resultado  da divisão  é: 2.0

# %%
# entrada

C = 5

# processamento

fahrenheit = (C*9/5)+ 32

# saída

print(f"resultado é:{fahrenheit}")
# Out:
# resultado é:41.0

# %%
# entrada

salario = float(3000)

# processamento

aumento = salario/100 * 10
novosalario = salario + aumento

# saída
print(f"novo salário é : {novosalario}")
# Out:
# novo salário é : 3300.0

# %%
# entrada

base = int(10)
altura = int(20)

# processamento

area = base * altura

# saída

print(f"resultado é : {area}")
# Out:
# resultado é : 200

# %%
# entrada

km = float (30)
litros = float(6)

# processamento

consumo = km/litros

# saída

print(f"consumo médio de combustível é: {consumo}")
# Out:
# consumo médio de combustível é: 5.0
